# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import pointbiserialr

df = pd.read_csv("data/featured_clinvar_result.csv")

# %%
# === Basic Dataset Summary ===
print("=== Dataset Info ===")
print(f"Shape: {df.shape}\n")
print(df.head())
print("\nMissing values:")
print(df.isnull().sum())
print("\nData types:")
print(df.dtypes)

# === Descriptive statistics ===
numeric_cols = df.select_dtypes(include=[np.number]).columns
print("\n=== Descriptive Statistics ===")
print(df[numeric_cols].describe())

# === Categorical summaries ===
if 'type' in df:
    print("\nType distribution:")
    print(df['type'].value_counts())

if 'label' in df:
    print("\nLabel distribution:")
    print(df['label'].value_counts())
# Out:
# === Dataset Info ===
# Shape: (1215, 29)
#
#     position  alignment_score  mc_synonymous_variant  mc_frameshift_variant  \
# 0  154021863               53                      0                      0
# 1  154021863               54                      0                      0
# 2  154022510              108                      0                      0
# 3  154022618              106                      0                      0
# 4  154024527              105                      0                      0
#
#    mc_3_prime_UTR_variant  mc_5_prime_UTR_variant  mc_splice_donor_variant  \
# 0                       1                       0                        0
# 1                       1                       0                        0
# 2                       1                       0                        0
# 3                       1                       0                        0
# 4                       1                       0                        0
#
#    mc_splice_acceptor_variant  mc_nonsense  mc_intron_variant  ...  prev_G  \
# 0                           0            0                  0  ...    True
# 1                           0            0                  0  ...    True
# 2                           0            0                  0  ...    True
# 3                           0            0                  0  ...   False
# 4                           0            0                  0  ...   False
#
#    prev_T  next_A  next_C  next_G  next_T  gc_content  position_bin  \
# 0   False   False   False    True   False    0.435644      0.987061
# 1   False   False   False    True   False    0.425743      0.987061
# 2   False   False   False   False    True    0.504950      0.987065
# 3   False   False   False    True   False    0.564356      0.987066
# 4   False   False   False    True   False    0.623762      0.987078
#
#    position_decile  chr_chrX
# 0                0      True
# 1                0      True
# 2                0      True
# 3                0      True
# 4                0      True
#
# [5 rows x 29 columns]
#
# Missing values:
# position                      0
# alignment_score               0
# mc_synonymous_variant         0
# mc_frameshift_variant         0
# mc_3_prime_UTR_variant        0
# mc_5_prime_UTR_variant        0
# mc_splice_donor_variant       0
# mc_splice_acceptor_variant    0
# mc_nonsense                   0
# mc_intron_variant             0
# mc_missense_variant           0
# mc_stop_lost                  0
# splice_distance               0
# label                         0
# region_exon                   0
# region_non-exon               0
# type                          0
# prev_A                        0
# prev_C                        0
# prev_G                        0
# prev_T                        0
# next_A                        0
# next_C                        0
# next_G                        0
# next_T                        0
# gc_content                    0
# position_bin                  0
# position_decile               0
# chr_chrX                      0
# dtype: int64
#
# Data types:
# position                        int64
# alignment_score                 int64
# mc_synonymous_variant           int64
# mc_frameshift_variant           int64
# mc_3_prime_UTR_variant          int64
# mc_5_prime_UTR_variant          int64
# mc_splice_donor_variant         int64
# mc_splice_acceptor_variant      int64
# mc_nonsense                     int64
# mc_intron_variant               int64
# mc_missense_variant             int64
# mc_stop_lost                    int64
# splice_distance                 int64
# label                           int64
# region_exon                      bool
# region_non-exon                  bool
# type                            int64
# prev_A                           bool
# prev_C                           bool
# prev_G                           bool
# prev_T                           bool
# next_A                           bool
# next_C                           bool
# next_G                           bool
# next_T                           bool
# gc_content                    float64
# position_bin                  float64
# position_decile                 int64
# chr_chrX                         bool
# dtype: object
#
# === Descriptive Statistics ===
#            position  alignment_score  mc_synonymous_variant  \
# count  1.215000e+03      1215.000000            1215.000000
# mean   1.540342e+08       101.086420               0.254321
# std    1.405017e+04        11.557176               0.435658
# min    1.540219e+08       -27.000000               0.000000
# 25%    1.540307e+08       101.000000               0.000000
# 50%    1.540310e+08       103.000000               0.000000
# 75%    1.540314e+08       106.000000               1.000000
# max    1.540977e+08       128.000000               1.000000
#
#        mc_frameshift_variant  mc_3_prime_UTR_variant  mc_5_prime_UTR_variant  \
# count            1215.000000             1215.000000             1215.000000
# mean                0.286420                0.051029                0.259259
# std                 0.452274                0.220147                0.438409
# min                 0.000000                0.000000                0.000000
# 25%                 0.000000                0.000000                0.000000
# 50%                 0.000000                0.000000                0.000000
# 75%                 1.000000                0.000000                1.000000
# max                 1.000000                1.000000                1.000000
#
#        mc_splice_donor_variant  mc_splice_acceptor_variant  mc_nonsense  \
# count              1215.000000                 1215.000000  1215.000000
# mean                  0.005761                    0.004115     0.063374
# std                   0.075716                    0.064044     0.243736
# min                   0.000000                    0.000000     0.000000
# 25%                   0.000000                    0.000000     0.000000
# 50%                   0.000000                    0.000000     0.000000
# 75%                   0.000000                    0.000000     0.000000
# max                   1.000000                    1.000000     1.000000
#
#        mc_intron_variant  mc_missense_variant  mc_stop_lost  splice_distance  \
# count        1215.000000          1215.000000   1215.000000      1215.000000
# mean            0.129218             0.247737      0.005761       112.868313
# std             0.335579             0.431876      0.075716       410.690365
# min             0.000000             0.000000      0.000000         0.000000
# 25%             0.000000             0.000000      0.000000        16.000000
# 50%             0.000000             0.000000      0.000000        46.000000
# 75%             0.000000             0.000000      0.000000        93.000000
# max             1.000000             1.000000      1.000000      7825.000000
#
#              label         type   gc_content  position_bin  position_decile
# count  1215.000000  1215.000000  1215.000000   1215.000000      1215.000000
# mean      0.479835     0.581070     0.606037      0.987140         4.495473
# std       0.499799     1.029133     0.088864      0.000090         2.876612
# min       0.000000     0.000000     0.178218      0.987061         0.000000
# 25%       0.000000     0.000000     0.550000      0.987117         2.000000
# 50%       0.000000     0.000000     0.623762      0.987119         4.000000
# 75%       1.000000     1.000000     0.663366      0.987122         7.000000
# max       1.000000     4.000000     0.851485      0.987547         9.000000
#
# Type distribution:
# type
# 0    817
# 1    246
# 3     94
# 4     31
# 2     27
# Name: count, dtype: int64
#
# Label distribution:
# label
# 0    632
# 1    583
# Name: count, dtype: int64

# %%
# === Visualization Section ===
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))

# Plot 1: Alignment Score
plt.subplot(2, 2, 1)
sns.histplot(df['alignment_score'], kde=True)
plt.title('Alignment Score Distribution')

# Plot 2: Splice Distance
plt.subplot(2, 2, 2)
sns.histplot(df['splice_distance'], kde=True)
plt.title('Splice Distance Distribution')

# Plot 3: Boxplot by Type
plt.subplot(2, 2, 3)
sns.boxplot(x='type', y='alignment_score', data=df)
plt.title('Alignment Score by Variant Type')

# Plot 4: Boxplot by Label
plt.subplot(2, 2, 4)
sns.boxplot(x='label', y='alignment_score', data=df)
plt.title('Alignment Score by Label')

plt.tight_layout()
plt.savefig('plots/distributions.png')
plt.close()

# %%
plt.figure(figsize=(12, 10))
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.savefig('plots/correlation_heatmap.png')
plt.close()

# %%
# === Statistical Tests ===
def group_comparison(df, group_col, target_col):
    groups = df[group_col].unique()
    if len(groups) == 2:
        t_stat, p = stats.ttest_ind(
            df[df[group_col] == groups[0]][target_col],
            df[df[group_col] == groups[1]][target_col],
            equal_var=False)
        print(f"T-test ({group_col} vs {target_col}): t={t_stat:.3f}, p={p:.4f}")
    elif len(groups) > 2:
        samples = [df[df[group_col] == g][target_col] for g in groups]
        f_stat, p = stats.f_oneway(*samples)
        print(f"ANOVA ({group_col} vs {target_col}): F={f_stat:.3f}, p={p:.4f}")

print("\n=== Statistical Group Comparisons ===")
group_comparison(df, 'label', 'alignment_score')
group_comparison(df, 'label', 'splice_distance')
group_comparison(df, 'type', 'alignment_score')
# Out:
# === Statistical Group Comparisons ===
# T-test (label vs alignment_score): t=7.263, p=0.0000
# T-test (label vs splice_distance): t=5.441, p=0.0000
# ANOVA (type vs alignment_score): F=104.581, p=0.0000

# %%
effect_cols = [col for col in df.columns if col.startswith("mc_")]
print("\n=== Point-Biserial Correlation with Label ===")
for col in effect_cols:
    corr, pval = pointbiserialr(df[col], df['label'])
    print(f"{col}: r={corr:.3f}, p={pval:.4f}")
# Out:
# === Point-Biserial Correlation with Label ===
# mc_synonymous_variant: r=-0.557, p=0.0000
# mc_frameshift_variant: r=0.660, p=0.0000
# mc_3_prime_UTR_variant: r=-0.223, p=0.0000
# mc_5_prime_UTR_variant: r=0.135, p=0.0000
# mc_splice_donor_variant: r=0.079, p=0.0057
# mc_splice_acceptor_variant: r=0.067, p=0.0196
# mc_nonsense: r=0.271, p=0.0000
# mc_intron_variant: r=-0.105, p=0.0003
# mc_missense_variant: r=-0.055, p=0.0550
# mc_stop_lost: r=0.079, p=0.0057

# %%
# === Scatter plots ===
if 'position' in df.columns:
    plt.figure(figsize=(10, 6))
    plt.scatter(df['position'], df['alignment_score'], alpha=0.4)
    plt.title('Position vs Alignment Score')
    plt.xlabel('Position')
    plt.ylabel('Alignment Score')
    plt.tight_layout()
    plt.savefig('plots/position_vs_score.png')
    plt.close()

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(effect_cols[:4]):
    plt.subplot(2, 2, i+1)
    sns.scatterplot(x='splice_distance', y=col, data=df)
    plt.title(f'Splice Distance vs {col}')

plt.tight_layout()
plt.savefig('plots/splice_distance_vs_effects.png')
plt.close()

# %%
print("\nAll analysis and plots completed. Files saved in 'plots/' directory.")
# Out:
# All analysis and plots completed. Files saved in 'plots/' directory.
